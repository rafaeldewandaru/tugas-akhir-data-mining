# %%
import pandas as pd
import os
from collections import Counter

# %%
def sentence_to_list(sentence):
    word_list = []
    word = ''
    for c in str(sentence).lower():
        if c.isalpha():
            word += c
        else:
            if word: word_list.append(word)
            word = ''
    if word: word_list.append(word)
    return word_list

# %%
def run_delta_analysis(dir_original, dir_corrected, output_report):
    changes = []
    files = [f for f in os.listdir(dir_original) if f.endswith('.csv')]
    
    print(f"Comparing {len(files)} files between directories...")
    
    for file in files:
        path_orig = os.path.join(dir_original, file)
        path_corr = os.path.join(dir_corrected, file)
        
        if not os.path.exists(path_corr):
            print(f"Missing corrected file for {file}")
            continue
            
        df_orig = pd.read_csv(path_orig)
        df_corr = pd.read_csv(path_corr)
        
        # Ensure row counts match before comparing
        if len(df_orig) != len(df_corr):
            print(f"Row count mismatch in {file}. Skipping.")
            continue
            
        for idx in range(len(df_orig)):
            # Compare Source Column (kalimat_asal)
            orig_asal_words = sentence_to_list(df_orig.loc[idx, 'kalimat_asal'])
            corr_asal_words = sentence_to_list(df_corr.loc[idx, 'kalimat_asal'])
            
            if len(orig_asal_words) == len(corr_asal_words):
                for w_o, w_c in zip(orig_asal_words, corr_asal_words):
                    if w_o != w_c:
                        changes.append((w_o, w_c, file))
                        
            # Compare Target Column (kalimat_tujuan)
            orig_tujuan_words = sentence_to_list(df_orig.loc[idx, 'kalimat_tujuan'])
            corr_tujuan_words = sentence_to_list(df_corr.loc[idx, 'kalimat_tujuan'])
            
            if len(orig_tujuan_words) == len(corr_tujuan_words):
                for w_o, w_c in zip(orig_tujuan_words, corr_tujuan_words):
                    if w_o != w_c:
                        changes.append((w_o, w_c, file))
                        
    # Aggregate and count all unique changes
    change_counts = Counter([(o, c) for o, c, f in changes])
    
    report_data = []
    for (orig, corr), count in change_counts.most_common():
        # Identify which dictionary files contain this specific error
        files_affected = list(set([f for o, c, f in changes if o == orig and c == corr]))
        file_string = ", ".join(files_affected[:3]) + ("..." if len(files_affected) > 3 else "")
        
        report_data.append({
            'Original_Word': orig,
            'Corrected_Word': corr,
            'Frequency': count,
            'Sample_Files': file_string
        })
        
    report_df = pd.DataFrame(report_data)
    report_df.to_csv(output_report, index=False)
    
    print(f"Analysis complete. Found {len(report_df)} unique spelling corrections.")
    return report_df

# Execute the crosscheck
dir_11 = '../Ekstraksi/11. Parallel Corpus'
dir_12 = '../Ekstraksi/12. Parallel Corpus - Spelling Checker'
report_path = '../csvAnalysis/Spelling_Delta_Report.csv'

report_df = run_delta_analysis(dir_11, dir_12, report_path)
display(report_df.head(20))
# Out:
# Comparing 68 files between directories...
# Missing corrected file for 12_Parcor.csv
# Missing corrected file for 13_Parcor.csv
# Missing corrected file for 15_Parcor.csv
# Missing corrected file for 19_Parcor.csv
# Missing corrected file for 1_Parcor.csv
# Missing corrected file for 21_Parcor.csv
# Missing corrected file for 22_Parcor.csv
# Missing corrected file for 23_Parcor.csv
# Missing corrected file for 24_Parcor.csv
# Missing corrected file for 25_Parcor.csv
# Missing corrected file for 26_Parcor.csv
# Missing corrected file for 27_Parcor.csv
# Missing corrected file for 28_Parcor.csv
# Missing corrected file for 29_Parcor.csv
# Missing corrected file for 2_Parcor.csv
# Missing corrected file for 31_Parcor.csv
# Missing corrected file for 32_Parcor.csv
# Missing corrected file for 33_Parcor.csv
# Missing corrected file for 34_Parcor.csv
# Missing corrected file for 35_Parcor.csv
# Missing corrected file for 36_Parcor.csv
# Missing corrected file for 37_Parcor.csv
# Missing corrected file for 38_Parcor.csv
# Missing corrected file for 3_Parcor.csv
# Missing corrected file for 41_Parcor.csv
# Missing corrected file for 42_Parcor.csv
# Missing corrected file for 43_Parcor.csv
# Missing corrected file for 44_Parcor.csv
# Missing corrected file for 45_Parcor.csv
# Missing corrected file for 46_Parcor.csv
# Missing corrected file for 48_Parcor.csv
# Missing corrected file for 4_Parcor.csv
# Missing corrected file for 50_Parcor.csv
# Missing corrected file for 51_Parcor.csv
# Missing corrected file for 52_Parcor.csv
# Missing corrected file for 54_Parcor.csv
# Missing corrected file for 55_Parcor.csv
# Missing corrected file for 56_Parcor.csv
# Missing corrected file for 57_Parcor.csv
# Missing corrected file for 58_Parcor.csv
# Missing corrected file for 5_Parcor.csv
# Missing corrected file for 60_Parcor.csv
# Missing corrected file for 61_Parcor.csv
# Missing corrected file for 62_Parcor.csv
# Missing corrected file for 63_Parcor.csv
# Missing corrected file for 66_Parcor.csv
# Missing corrected file for 67_Parcor.csv
# Missing corrected file for 68_Parcor.csv
# Missing corrected file for 70_Parcor.csv
# Missing corrected file for 71_Parcor.csv
# Missing corrected file for 77_Parcor.csv
# Missing corrected file for 78_Parcor.csv
# Missing corrected file for 79_Parcor.csv
# Missing corrected file for 84_Parcor.csv
# Missing corrected file for 85_Parcor.csv
# Missing corrected file for 87_Parcor.csv
# Missing corrected file for 89_Parcor.csv
# Missing corrected file for 8_Parcor.csv
# Missing corrected file for 91_Parcor.csv
# Missing corrected file for 94_Parcor.csv
# Missing corrected file for 9_Parcor.csv
# Analysis complete. Found 8716 unique spelling corrections.
#     Original_Word Corrected_Word  Frequency   Sample_Files
# 0      menanamnya     menantunya          1  10_Parcor.csv
# 1       ngehambur      ngahambur          1  10_Parcor.csv
# 2        sabalupm        sabalun          1  10_Parcor.csv
# 3         ndulone          nulon          1  10_Parcor.csv
# 4           faran          jaran          1  10_Parcor.csv
# 5            luju           tuju          1  10_Parcor.csv
# 6          fangil         langil          1  10_Parcor.csv
# 7        keadaatn        keadaan          1  10_Parcor.csv
# 8        mangkitn        mungkin          1  10_Parcor.csv
# 9        menurlll        menurul          1  10_Parcor.csv
# 10        fakilah        iakilah          1  10_Parcor.csv
# 11         cepala         kepala          1  10_Parcor.csv
# 12        sebujur        sekujur          1  10_Parcor.csv
# 13       kelnarau       kernarau          1  10_Parcor.csv
# 14         sulnur          sulur          1  10_Parcor.csv
# 15       diluruli       dituruti          1  10_Parcor.csv
# 16       hercocok       bercocok          1  10_Parcor.csv
# 17  kecurangannya  kekurangannya          1  10_Parcor.csv
# 18        keslifi         kesini          1  10_Parcor.csv
# 19        kawokng         kalong          1  10_Parcor.csv
